# %%
# !tar xvf cifar_teachers.tar
# Out:
# x cifar_teachers/
# x cifar_teachers/resnet110_vanilla/
# x cifar_teachers/resnet110_vanilla/ckpt_epoch_240.pth
# x cifar_teachers/ResNet50_vanilla/
# x cifar_teachers/ResNet50_vanilla/ckpt_epoch_240.pth
# x cifar_teachers/resnet32x4_vanilla/
# x cifar_teachers/resnet32x4_vanilla/ckpt_epoch_240.pth
# x cifar_teachers/resnet56_vanilla/
# x cifar_teachers/resnet56_vanilla/ckpt_epoch_240.pth
# x cifar_teachers/vgg13_vanilla/
# x cifar_teachers/vgg13_vanilla/ckpt_epoch_240.pth
# x cifar_teachers/wrn_40_2_vanilla/
# x cifar_teachers/wrn_40_2_vanilla/ckpt_epoch_240.pth
